# %% [markdown]
# ### Question number 1

# %% [markdown]
# Data visualization is important in data analysis because of the following reasons:
# * It helps to make complex data more accessible and understandable.
# * It reveals patterns and trends that may not be immediately obvious in raw data, aiding in decision-making.
# * It allows analysts to convey insights and findings in a clear and concise manner.

# %% [markdown]
# ### Question number 2

# %% [markdown]
# The three graphs used in statistical studies to describe the distribution of samples are:
# * Box plot: It shows the distribution of data based on five summary statistics: minimum, first quartile, median, third quartile, and maximum. It displays the range and distribution of the data and can highlight any potential outliers or skewness.
# * Scatter plot: It shows the relationship between two continuous variables displaying each observation as a point which can be used to identify any patterns or correlations in the data.
# * Density plot: It shows the distribution of continuous data as a smooth curve providing a visual representation of the data’s probability density function and is useful for comparing distributions.

# %% [markdown]
# ### Question number 3

# %% [markdown]
# The difference between a histogram and a bar chart are:
#
# A bar chart displays a categorical data set in relation to a numerical data set. For example, Consider a bar graph
# where the x-axis represents the year of college (freshman, sophomore, junior, or senior) and the
# y-axis represents the amount of hours studied per week. It is employed to quantify the quantity in
# a categorical dataset.
#
# A histogram is a diagram that displays the connection between two numerical variables. It is
# employed to display how data are distributed. For example, the number of students achieving a
# particular GPA on the y-axis and the GPA of college students on the X-axis.

# %% [markdown]
# ### Question number 4

# %% [markdown]
# #### Question number 4 a)

# %%
import pandas as pd
import matplotlib.pyplot as plt
url = 'http://becomingvisual.com/python4data/timeseries_stockprice.csv'
df = pd.read_csv(url)
df.tail()
# Out:
#        Date   Amazon  Google  Facebook
# 17  5/24/18   976.00  952.98    148.51
# 18  5/25/18   984.85  957.33    150.30
# 19  5/29/18   995.00  969.70    152.23
# 20  5/30/18   996.51  970.31    151.97
# 21  5/31/18  1000.00  975.02    152.70

# %% [markdown]
# #### Question number 4 b)

# %%
print("Rows:",df.shape[0])
print("Columns:",df.shape[1])
# Out:
# Rows: 22
# Columns: 4

# %% [markdown]
# #### Question number 4 c)

# %%
amazon = df.plot.line(x= 'Date', y = 'Amazon', ylabel = 'Stock Price')

# %% [markdown]
# The stock price of Amazon rises and falls across the month of May. During the first couple day,
# starting at around \\$930, it rises and then falls. It falls during 12 and 20 May, but none of the falls
# are lower than the price the Amazon had at the first of May. After May 20, the Amazon stock
# price continually increase upto \\$1,000 by the end of the month.

# %% [markdown]
# #### Question number 4 d)

# %%
df.set_index('Date', inplace=True)
df.plot(title='Stock Prices')
# Out:
# <AxesSubplot:title={'center':'Stock Prices'}, xlabel='Date'>

# %% [markdown]
# Overall, it appears that Facebook’s stock price is considerably lower than those of Google and
# Amazon. But while Amazon and Google’s and Facebook’s stock prices generally increased over the
# month, Facebook’s stock price remained rather steady.
#
# According to the subplots, each company’s stock price fell after May 15 for a few days before rising.

# %% [markdown]
# ### Question number 5

# %% [markdown]
# #### Question number 5 a)

# %%
url = 'http://becomingvisual.com/python4data/tv.csv'
df = pd.read_csv(url)
plt.scatter(x='av_rating', y='seasonNumber', data=df)
plt.xlabel('Season Number')
plt.ylabel('Average Rating')
plt.title('TV Show Ratings vs Season Number')
plt.show()

# %% [markdown]
# #### Question number 5 b)

# %%
transformed = df.copy()
transformed = transformed[(transformed['seasonNumber'] > 6)]
plt.scatter(x='av_rating', y='seasonNumber', data=transformed)
plt.xlabel('Average Rating')

plt.ylabel('Number of Seasons')
plt.title('Average Rating VS Number of Seasons')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Question number 5 c)

# %% [markdown]
# The first scatter plot shows the relationship between average rating and season number for all TV shows in the dataset. The second scatter plot, on the other hand, shows the relationship only for shows that have been on for seven or more seasons. The second plot provides a more accurate representation of the relationship between average rating and season number, as shorter-lived shows may have a different rating pattern than longer-lived shows.
